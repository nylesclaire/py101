# %% [markdown]
# Question 1

# %%
# Method 1

numbers = [1, 2, 3, 4]
numbers.clear()
print(numbers)
# Out:
# []

# %%
# Method 2
numbers = [1, 2, 3, 4]
del numbers[:]
print(numbers)
# Out:
# []

# %% [markdown]
# Question 2

# %% [markdown]
# [1, 2, 3, 4, 5]

# %%
print([1, 2, 3] + [4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Question 3

# %% [markdown]
# "hello there"

# %%
str1 = "hello there"
str2 = str1
str2 = "goodbye!"
print(str1)
# Out:
# hello there

# %% [markdown]
# Question 4

# %% [markdown]
# [{"first": 42}, {"second": "value2"}, 3, 4, 5]

# %%
my_list1 = [{"first": "value1"}, {"second": "value2"}, 3, 4, 5]
my_list2 = my_list1.copy()
my_list2[0]['first'] = 42
print(my_list1)
# Out:
# [{'first': 42}, {'second': 'value2'}, 3, 4, 5]

# %% [markdown]
# Question 5

# %%
#Rewrite this 
def is_color_valid(color):
    if color == "blue" or color == "green":
        return True
    else:
        return False
    
#method 1
def is_color_valid_2(color):
    return (color in ["blue", "green"])

print(is_color_valid_2("blue"))
print(is_color_valid_2("red"))
# Out:
# True
# False

# %%
#method 2
def is_color_valid_3(color):
    return color == "blue" or color == "green"

print(is_color_valid_2("blue"))
print(is_color_valid_2("red"))
# Out:
# True
# False
