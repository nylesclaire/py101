# %% [markdown]
# #### Question 1

# %% [markdown]
# No, the second one will not run as expected since the curly brace should be on the same line as the return statement. That function will return None.

# %% [markdown]
# #### Question 2

# %% [markdown]
# {'first' : [1,2]}

# %% [markdown]
# #### Question 3

# %% [markdown]
# A
#
# "one is: ["one"]"
#
# "two is: ["two"]"
#
# "three is: ["three"]"

# %% [markdown]
# B
#
# "one is: ["one"]"
#
# "two is: ["two"]"
#
# "three is: ["three"]"

# %% [markdown]
# C
#
# "one is: ["two"]"
#
# "two is: ["three"]"
#
# "three is: ["one"]"

# %% [markdown]
# #### Question 4

# %%
def is_an_ip_number(str):
    if str.isdigit():
        number = int(str)
        return 0 <= number <= 255
    return False

def is_dot_separated_ip_address(input_string):
    dot_separated_words = input_string.split(".")
    if len(dot_separated_words) != 4:
        return False
    while len(dot_separated_words) > 0:
        word = dot_separated_words.pop()
        if not is_an_ip_number(word):
            return False
    return True

print(is_dot_separated_ip_address("10.4.5.11"))
print(is_dot_separated_ip_address("3.56.7"))
print(is_dot_separated_ip_address("seven.89.46.five"))
# Out:
# True
# False
# False

# %% [markdown]
# #### Question 5

# %% [markdown]
# A NameError will be thrown because 'greeting' has not been initialized.
